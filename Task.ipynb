# %%
import time
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\P nageswararao\OneDrive\Desktop\data fsds\task\FitBit data.csv')

# %%
# 1.A)Read this dataset in pandas

df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#3.A)convert all the dates avaible in dataset to timestamp format in pandas

df['converted_ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# 4.A)Find out in this data that how many unique id's we have

df['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(df['Id'].unique())
# Out:
# 35

# %%
#5.A)which id is one of the active id that you have in whole dataset

df[df['VeryActiveDistance'] == df['VeryActiveDistance'].max()]['Id']
# Out:
# 454    8877689391
# Name: Id, dtype: int64

# %%
#6.A)how many of them have not logged there activity find out in terms of number of ids


len(df[(df['LoggedActivitiesDistance'] == 0.0) & (df['SedentaryActiveDistance']==0.0)]['Id'])
# Out:
# 398

# %%
#7.A)Find out who is the laziest person id that we have in dataset

df[df['Calories'] == df['Calories'].min()]['Id']
# Out:
# 134    2873212765
# 240    4319703577
# 290    4702921684
# 323    6117666160
# 412    8253242879
# Name: Id, dtype: int64

# %%
#8.A) Explore over an internet that how much calories burn is required for a healthy person and 
#find out how many healthy person we have in our dataset


#for an healthy person ,500 to 1000 claloriees are to be burnt.

df[df['Calories'] == df['Calories'].between(500,1000)]['Id']
# Out:
# 134    2873212765
# 240    4319703577
# 290    4702921684
# 323    6117666160
# 412    8253242879
# Name: Id, dtype: int64

# %%
#9.A)how many person are not a regular person with respect to activity try to find out those
E = dict((df.groupby(['Id'])['converted_ActivityDate'].count())<10)

# %%
E
# Out:
# {1503960366: False,
#  1624580081: False,
#  1644430081: False,
#  1844505072: False,
#  1927972279: False,
#  2022484408: False,
#  2026352035: False,
#  2320127002: False,
#  2347167796: False,
#  2873212765: False,
#  2891001357: True,
#  3372868164: False,
#  3977333714: False,
#  4020332650: False,
#  4057192912: False,
#  4319703577: False,
#  4388161847: True,
#  4445114986: False,
#  4558609924: False,
#  4702921684: False,
#  5553957443: False,
#  5577150313: False,
#  6117666160: False,
#  6290855005: False,
#  6391747486: True,
#  6775888955: True,
#  6962181067: False,
#  7007744171: False,
#  7086361926: False,
#  8053475328: False,
#  8253242879: False,
#  8378563200: False,
#  8583815059: True,
#  8792009665: False,
#  8877689391: False}

# %%
[key for key, value in E.items() if value == True]
# Out:
# [2891001357, 4388161847, 6391747486, 6775888955, 8583815059]

# %%
F = dict(df.groupby(['Id'])['Calories'].sum().sort_values())

# %%
F
# Out:
# {4388161847: 14442,
#  6391747486: 15868,
#  2026352035: 16266,
#  3977333714: 16777,
#  8253242879: 17556,
#  2891001357: 18187,
#  2320127002: 18385,
#  3372868164: 18603,
#  8583815059: 19130,
#  1844505072: 19391,
#  2873212765: 20349,
#  6117666160: 20993,
#  5553957443: 21630,
#  6290855005: 21656,
#  4558609924: 21962,
#  4319703577: 23931,
#  6775888955: 24523,
#  8792009665: 24884,
#  1624580081: 25705,
#  7086361926: 26124,
#  1927972279: 27048,
#  1644430081: 29164,
#  6962181067: 29249,
#  2022484408: 29704,
#  2347167796: 30320,
#  7007744171: 31525,
#  4445114986: 31617,
#  8053475328: 31825,
#  1503960366: 34128,
#  5577150313: 36303,
#  8378563200: 40274,
#  8877689391: 41414,
#  4702921684: 42322,
#  4057192912: 60913,
#  4020332650: 98412}

# %%
#10 . who is the thired most active person in this dataset find out those in pandas

print("The third most active person :",[ id for id,count in F.items() if count == 42322])
# Out:
# The third most active person : [4702921684]

# %%
#11 . who is the 5th most laziest person avilable in dataset find it out

print("The  fifth  most lazy person :",[ id for id,count in F.items() if count == 17556])
# Out:
# The  fifth  most lazy person : [8253242879]

# %%
#12 . what is a totla acumulative calories burn for a person find out

G = dict(df.groupby(['Id'])['Calories'].cumsum().sort_values())

# %%
G
# Out:
# {153: 1288,
#  96: 1324,
#  123: 1335,
#  19: 1373,
#  84: 1407,
#  401: 1429,
#  197: 1777,
#  0: 1819,
#  334: 1820,
#  143: 1852,
#  241: 1878,
#  264: 1902,
#  135: 1920,
#  229: 1958,
#  48: 1969,
#  249: 2010,
#  108: 2041,
#  291: 2142,
#  314: 2210,
#  352: 2244,
#  433: 2260,
#  425: 2360,
#  378: 2496,
#  366: 2573,
#  60: 2590,
#  20: 2637,
#  85: 2644,
#  72: 2645,
#  97: 2648,
#  324: 2778,
#  154: 2778,
#  402: 2858,
#  276: 2886,
#  124: 2894,
#  165: 2990,
#  343: 3065,
#  38: 3323,
#  390: 3377,
#  445: 3527,
#  198: 3554,
#  265: 3582,
#  303: 3625,
#  413: 3669,
#  242: 3756,
#  292: 3757,
#  136: 3840,
#  49: 3858,
#  144: 3921,
#  98: 3972,
#  1: 3973,
#  86: 3974,
#  21: 3987,
#  250: 4042,
#  335: 4044,
#  230: 4099,
#  379: 4137,
#  109: 4228,
#  403: 4287,
#  155: 4408,
#  353: 4432,
#  73: 4685,
#  125: 4739,
#  426: 4877,
#  315: 5094,
#  367: 5148,
#  293: 5238,
#  434: 5264,
#  344: 5272,
#  99: 5296,
#  22: 5329,
#  61: 5373,
#  166: 5470,
#  266: 5483,
# ...

# %% [markdown]
# # task 2 - Superstore_USA

# %% [markdown]
# 1.Load the dataset in pandas

# %%
df1 = pd.read_excel(r'C:\Users\P nageswararao\OneDrive\Desktop\data fsds\task\Superstore_USA.xlsx',sheet_name=0)

# %%
df1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df1.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df2 = pd.read_excel(r'C:\Users\P nageswararao\OneDrive\Desktop\data fsds\task\Superstore_USA.xlsx',sheet_name=1)

# %%
df2.dtypes
# Out:
# Order ID     int64
# Status      object
# dtype: object

# %%
df2.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
df3 = pd.read_excel(r'C:\Users\P nageswararao\OneDrive\Desktop\data fsds\task\Superstore_USA.xlsx',sheet_name=2)

# %%
df3
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df2.groupby('Status')['Order ID'].apply(print)
# Out:
# 0           65
# 1          612
# 2          614
# 3          678
# 4          710
#          ...
# 1629    182681
# 1630    182683
# 1631    182750
# 1632    182781
# 1633    182906
# Name: Returned, Length: 1634, dtype: int64
# Status
# Returned    None
# Name: Order ID, dtype: object

# %%
#4 . try  to join order and return data in  pandas

combo =  df1.join(df2,on='Order ID', lsuffix='_luffix',rsuffix='_rsuufix')
combo
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#5 ) Try to find out how many unique customer that we have 
print("The number of unique customers are:",len(df1['Customer ID'].unique()))
# Out:
# The number of unique customers are: 2703

# %%
#6) try to find out in how many regions we are selling a product and who is a manager for a respective region 

(df3['Region'].unique())
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
(df3.groupby('Region')['Manager']).apply(print)
# Out:
# 0    Chris
# Name: Central, dtype: object
# 1    Erin
# Name: East, dtype: object
# 2    Sam
# Name: South, dtype: object
# 3    William
# Name: West, dtype: object
# Region
# Central    None
# East       None
# South      None
# West       None
# Name: Manager, dtype: object

# %%
b = (df3.groupby('Region')['Manager'])
for i in b:
    print(i)
# Out:
# ('Central', 0    Chris
# Name: Manager, dtype: object)
# ('East', 1    Erin
# Name: Manager, dtype: object)
# ('South', 2    Sam
# Name: Manager, dtype: object)
# ('West', 3    William
# Name: Manager, dtype: object)

# %%
#7)find out how many different shipement mode that we have and 
#what is a percentage usablity of all the shipment mode with respect to dataset

df1['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
# 8) Create a new coulmn and try to find our a diffrence between order date and shipment date

df1['Days_to_deliver'] = (df1['Ship Date'] - df1['Order Date']).dt.days
df1['Days_to_deliver']
# Out:
# 0       2
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 9421    1
# 9422    0
# 9423    2
# 9424    3
# 9425    2
# Name: Days_to_deliver, Length: 9426, dtype: int64

# %%
# 9) base on question number 8 find out for which order id we have shipment duration more than 10 days
df1[df1['Days_to_deliver'] > 10]['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
# 10) Try to find out a list of a returned order which sihpment duration was more then 15 days and 
# find out that region manager as well.
list[combo[combo['Days_to_deliver'] > 15]['Order ID_luffix']]
# Out:
# list[643     87215
# 1678    87957
# 1680    87957
# 1697    19556
# 1699    19556
# 2515    86177
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID_luffix, dtype: int64]

# %%
dfs = pd.concat([df1,df2,df3],axis=1)

# %%
dfs
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dfs.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Days_to_deliver',
#        'Order ID', 'Status', 'Region', 'Manager'],
#       dtype='object')

# %%
dfs[dfs['Days_to_deliver'] > 15]['Manager']
# Out:
# 643     NaN
# 1678    NaN
# 1680    NaN
# 1697    NaN
# 1699    NaN
# 2515    NaN
# 5673    NaN
# 5859    NaN
# 5881    NaN
# 8607    NaN
# 8609    NaN
# 8610    NaN
# 8973    NaN
# 8982    NaN
# 8983    NaN
# 8993    NaN
# 8996    NaN
# 8997    NaN
# Name: Manager, dtype: object

# %%
dfs.drop('Region',inplace=True,axis=1)

# %%
# 11)  . Gorup by region and find out which region is more profitable


a = dict(dfs.groupby('Region')['Profit'].sum().sort_values())
a
# Out:
# {'South': 104201.19241958998,
#  'West': 310849.4538968,
#  'East': 377566.18604466,
#  'Central': 519825.56706659996}

# %%
def get_key(val):
    for key,value in a.items():
        if val ==  value:
            return key

# %%
print("The most profitable region is :",get_key(519825.56706659996))
# Out:
# The most profitable region is : Central

# %%
#13)  Give me a list of unique postal code 

list(dfs['Postal Code'].unique())
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %%
#14)  . which customer segement is more profitalble find it out


a = dict(dfs.groupby(['Customer Segment'])['Profit'].sum().sort_values())

# %%
a
# Out:
# {'Consumer': 206559.62534845597,
#  'Home Office': 283869.5538145,
#  'Small Business': 316474.59248165396,
#  'Corporate': 505538.62778304}

# %%
print("The most profitable customer segment is :",get_key(505538.62778304))
# Out:
# The most profitable customer segment is : Corporate

# %%
#15)  try to find out the 10th most loss making product catagory 

c = dfs.groupby('Product Name')['Profit'].sum().sort_values()

# %%
c[0:10]
# Out:
# Product Name
# Okidata Pacemark 4410N Wide Format Dot Matrix Printer                            -39743.177832
# Polycom ViewStation™ ISDN Videoconferencing Unit                                 -36446.423528
# Epson DFX-8500 Dot Matrix Printer                                                -29557.665792
# Global High-Back Leather Tilter, Burgundy                                        -23236.837560
# Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table   -14874.638164
# Hoover Portapower™ Portable Vacuum                                               -14120.392820
# Large Capacity Hanging Post Binders                                              -12442.721780
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                -11541.176706
# KI Conference Tables                                                             -10066.260905
# Eldon ClusterMat Chair Mat with Cordless Antistatic Protection                    -9543.652500
# ...

# %%
#16)   Try to find out 10 top  product with highest margins

d = dfs.groupby('Product Name')['Product Base Margin'].sum().sort_values()

# %%
d
# Out:
# Product Name
# SAFCO Commercial Wire Shelving, Black                                                0.00
# SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black     0.00
# Safco Contoured Stacking Chairs                                                      0.00
# SAFCO Arco Folding Chair                                                             0.00
# SAFCO Boltless Steel Shelving                                                        0.00
#                                                                                     ...
# Accessory36                                                                         14.11
# Adesso Programmable 142-Key Keyboard                                                15.45
# Bevis 36 x 72 Conference Tables                                                     16.38
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                   18.33
# ...

# %%
d[-1:-11:-1]
# Out:
# Product Name
# Global High-Back Leather Tilter, Burgundy                                                    19.98
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                            18.33
# Bevis 36 x 72 Conference Tables                                                              16.38
# Adesso Programmable 142-Key Keyboard                                                         15.45
# Accessory36                                                                                  14.11
# Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms    13.64
# Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum                13.26
# Microsoft Internet Keyboard                                                                  13.21
# StarTAC 7760                                                                                 12.98
# ...
